# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wasim/Data-Science/blob/main/data-analyst-roadmap/03_pandas/02_data_manipulation.ipynb)

# %% [markdown]
# # Data Manipulation with Pandas
# Learn how to filter, sort, and clean your data.

# %%
import pandas as pd
import numpy as np

# %%
# Create a sample DataFrame
df = pd.DataFrame({
    'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
    'C': np.random.randn(8),
    'D': np.random.randn(8)
})

# %% [markdown]
# ## Filtering

# %%
# Boolean indexing
df[df['A'] == 'foo']

# %%
# Multiple conditions
df[(df['A'] == 'foo') & (df['C'] > 0)]

# %% [markdown]
# ## Missing Data

# %%
# Introduce missing data
df.loc[0, 'C'] = np.nan
df.loc[1, 'D'] = np.nan
df

# %%
# Check for missing values
df.isna()

# %%
# Drop rows with missing values
df.dropna()

# %%
# Fill missing values
df.fillna(value=0)

# %% [markdown]
# ## Sorting

# %%
df.sort_values(by='C')

# %% [markdown]
# ## String Operations

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
