# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wasim/Data-Science/blob/main/data-analyst-roadmap/04_data_visualization/01_matplotlib_basics.ipynb)

# %% [markdown]
# # Matplotlib Basics
# Master the foundation of plotting in Python.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Line Plots

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.show()

# %% [markdown]
# ## Scatter Plots

# %%
x = np.random.randn(100)
y = np.random.randn(100)
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## Bar Charts

# %%
plt.bar(['A', 'B', 'C'], [1, 3, 2])
plt.show()

# %% [markdown]
# ## Histograms

# %%
data = np.random.normal(0, 1, 1000)
plt.hist(data, bins=30)
plt.show()

# %% [markdown]
# ## Customization

# %%
plt.plot(x, np.sin(x), label='Sine')
plt.title('Sine Wave')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()
