# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wasim/Data-Science/blob/main/data-analyst-roadmap/04_data_visualization/02_seaborn_advanced.ipynb)

# %% [markdown]
# # Advanced Visualization with Seaborn
# Create statistical graphics that are attractive and informative.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load dataset
tips = sns.load_dataset('tips')
tips.head()

# %% [markdown]
# ## Distribution Plots

# %%
sns.histplot(data=tips, x='total_bill', kde=True)
plt.show()

# %% [markdown]
# ## Categorical Plots

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
plt.show()

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# ## Relationship Plots

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', data=tips)
plt.show()

# %%
sns.pairplot(tips, hue='sex')
plt.show()

# %% [markdown]
# ## Heatmaps

# %%
corr = tips.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()
